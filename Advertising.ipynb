# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
data=pd.read_csv('Advertising.csv')

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.shape
# Out:
# (200, 4)

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
plt.scatter(x=data.TV,y=data.Sales)   #checking the corelation

# %%
plt.style.use('seaborn')
sns.pairplot(data,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',height=6,aspect=1,kind='reg')
# Out:
# C:\Users\jijin\AppData\Local\Temp\ipykernel_28676\105058747.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
X=data.iloc[:,:3]
y=data.iloc[:,3]

# %%
print(X.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2) #splitting the data

# %%
#apply the linear regression model

#step1:to import the model from sklearn package
from sklearn.linear_model import LinearRegression
#step2:to instantiate the ml model
reg=LinearRegression()
#step3:to fit the training data to the model
reg.fit(X_train,y_train) #optimize the theta value
# Out:
# LinearRegression()

# %%
#step4:predict the model
y_pred = reg.predict(X_test)
print(y_pred.shape)
print(y_pred)
# Out:
# (40,)
# [11.65025376 12.22870565 17.28817086  9.94771665  8.59510823 12.94233893
#  17.8401141  10.49648877 17.13583795 13.80449686  7.67139251 13.42980959
#   6.10372706  4.52275302 14.13508607 14.89047728 14.72570813 21.37520619
#   3.8680889  15.27905848 15.73894033  9.76958789 17.8915605  16.70585807
#  14.44251436 14.38204291 17.26192863 20.00880378 15.40735341  8.24991908
#  10.61594742 19.39871014 18.22042663  8.97643141  7.17047461  8.51790415
#   8.17379087 13.87669289 21.05511448 18.32462797]

# %%
print(reg.coef_)#theta 1,2,3
print(reg.intercept_)#theta 0
# Out:
# [ 0.04629335  0.19099597 -0.00633412]
# 3.0752086972641095

# %%
X_sam=X_test.iloc[0,:3].values
wght=np.array(reg.coef_)      #manually taking one value and predicting that value

# %%
coeff_mul=X_sam*wght
pred_val=coeff_mul.sum() + reg.intercept_

# %%
pred_val   #now we can see that the y_pred first value and the result after calculating pred_val are same
# Out:
# 11.650253757548716

# %%
score=r2_score(y_test,y_pred)    #r2score
print(score)
# Out:
# 0.7745456642436043

# %%
X_train.shape
# Out:
# (160, 3)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

def polyRegression(degree,**kwargs):
    return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

# %%
#validation curve is used to find the perfect degree to be applied on the polynomial regression
from sklearn.model_selection import validation_curve
degree = np.arange(0, 21)
train_score, val_score = validation_curve(polyRegression(degree), X, y,
                                          param_name='polynomialfeatures__degree',param_range= degree, cv=7)
plt.plot(degree, np.median(train_score, 1), color='blue', label='training score')
plt.plot(degree, np.median(val_score, 1), color='red', label='validation score')
plt.ylim(0,1)
plt.legend(loc='best')

# %%
poly_model = polyRegression(degree=2) #from above curve we came to know degree 2 is the perfect fit

# %%
y_pred = poly_model.fit(X_train, y_train).predict(X_test)

# %%
poly_model
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
from sklearn.metrics import r2_score #r2score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9560555755181691
